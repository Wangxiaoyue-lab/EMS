# %%
library(SeuratDisk)
library(Seurat)
library(CellChat)
library(patchwork)
library(ggplot2)
options(stringsAsFactors = FALSE)
getwd()
setwd("/home/liusong/scRNA/endometriosis/V2data/scanpy/21samples/cellchat")

#Convert("OMAdata_umap_leiden_BBKNN.h5ad", dest = "h5seurat", overwrite = F)  #change h5ad to h5seurat, and get an new h5seurat file in the same dir of h5ad file.
#sc <- LoadH5Seurat("Menstrual_effluent_scRNA.h5seurat",meta.data = T, misc=F) # load the h5surat file, misc=F was opitional
#saveRDS(sc,file="OMAdata_umap_leiden_BBKNN.rds")

OMAdata<-readRDS("../OMAdata_umap_leiden_BBKNN.rds")
head(OMAdata@meta.data)
Idents(OMAdata)<-"newtype"
input<- GetAssayData(OMAdata,slot = "data")
meta<-data.frame(labels=Idents(OMAdata),row.names=names(Idents(OMAdata)))
cellchat<-createCellChat(object=input,meta=meta,group.by="labels")
#cellchat<-createCellChat(object=input,group.by="newtype")
cellchat
summary(cellchat)
levels(cellchat@idents)
groupSize<-as.numeric(table(cellchat@idents))
groupSize
CellChatDB<-CellChatDB.human
str(CellChatDB)
colnames(CellChatDB$interaction)
head(CellChatDB$interaction)
head(CellChatDB$cofactor)
head(CellChatDB$geneInfo)
showDatabaseCategory(CellChatDB)
unique(CellChatDB$interaction$annotation)
# Out:
# Attaching package: 'cowplot'
#
#
# The following object is masked from 'package:patchwork':
#
#     align_plots
# [1] "/home/liusong/scRNA/endometriosis/V2data/scanpy/21samples/cellchat"
#                     n_genes_by_counts total_counts total_counts_mt
# AAACCTGAGTGCAAGC-14 2051               5086         216
# AAACCTGTCAATCACG-14 5610              23666        1138
# AAACCTGTCATTGCGA-14 2326               6108         329
# AAACCTGTCGAACTGT-14 2790               7891         317
# AAACGGGCACTTAACG-14 1970               4807         151
# AAACGGGCATGCCTTC-14 1387               3128         126
#                     pct_counts_mt n_genes sampleID Phase leiden louvain
# AAACCTGAGTGCAAGC-14 4.246953      2050    14       P     0      1
# AAACCTGTCAATCACG-14 4.808586      5610    14       P     4      5
# AAACCTGTCATTGCGA-14 5.386379      2326    14       P     0      6
# AAACCTGTCGAACTGT-14 4.017235      2790    14       P     11     10
# ...

# %%
CellChatDB.use <- subsetDB(CellChatDB, search = "Secreted Signaling")
cellchat@DB <- CellChatDB.use
cellchat <- subsetData(cellchat)
future::plan("multisession", workers =8) 
cellchat <- identifyOverExpressedGenes(cellchat)
cellchat <- identifyOverExpressedInteractions(cellchat)
cellchat <- projectData(cellchat, PPI.human)
cellchat <- computeCommunProb(cellchat)
cellchat <- filterCommunication(cellchat, min.cells = 10)
df.net <- subsetCommunication(cellchat)

cellchat <- computeCommunProbPathway(cellchat)
df.netp<-subsetCommunication(cellchat, slot.name="netP")

cellchat <- aggregateNet(cellchat)
# Out:
# triMean is used for calculating the average gene expression per cell group.
# [1] ">>> Run CellChat on sc/snRNA-seq data <<< [2024-05-28 18:13:33.077969]"
# [1] ">>> CellChat inference is done. Parameter values are stored in `object@options$parameter` <<< [2024-05-28 18:33:45.341258]"

# %%
cellchat<-updateClusterLabels(cellchat,new.order=c("Ecstroma",'OstromaB','Ostroma','endothelia','pericyte','LEC','macrophage','T','B','mast'))
pcount<-netVisual_heatmap(cellchat,color.heatmap="Reds",measure=c("count")) 
pweight<-netVisual_heatmap(cellchat,color.heatmap="Reds",measure="weight")
pcount+pweight 
pdf("ourOMA_circle_plot_each_weight.pdf",width = 10,height = 10)
mat <- cellchat@net$weight   #mat <- cellchat@net$count
par(mfrow =c(3,3),xpd=T)
for (i in 1:nrow(mat)){
    mat2 <- matrix(0,nrow = nrow(mat),ncol = ncol(mat),dimnames = dimnames(mat))
    mat2[i,] <- mat[i,] 
    netVisual_circle(mat2,vertex.weight = groupSize, weight.scale = T,label.edge=T,arrow.size = 0.8, edge.width.max = 2.5,title.name = rownames(mat)[i])
}
dev.off()
pdf(file="ourOMA_interaction_strength_heatmap.pdf",width=5,height=5)
pweight
dev.off()
cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP")
ht1 <- netAnalysis_signalingRole_heatmap(cellchat, pattern = "outgoing",height=15)
ht2 <- netAnalysis_signalingRole_heatmap(cellchat, pattern = "incoming",height=15)
pdf(file="ourOMA_signaling_netp_heatmap.pdf",width=18,height=20)
ht1
ht2
dev.off()
saveRDS(cellchat, file = "cellchat_myOMA_LS.rds")
# Out:
# Only reorder cell groups but do not rename cell groups!
# Reorder cell groups!
# The cell group order before reordering is  Ostroma endothelia LEC pericyte OstromaB T macrophage Ecstroma mast B
# The cell group order after reordering is  Ecstroma OstromaB Ostroma endothelia pericyte LEC macrophage T B mast
# We now re-run computeCommunProbPathway`,`aggregateNet`, and `netAnalysis_computeCentrality`...
#
# Do heatmap based on a single object
#
#
# Do heatmap based on a single object
# png
#   2
# png
#   2
# png
#   2
# plot without title

# %%
cellchat<-readRDS(file = "cellchat_myOMA_LS.rds")
cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP")
ht1 <- netAnalysis_signalingRole_heatmap(cellchat, pattern = "outgoing",height=15)
ht2 <- netAnalysis_signalingRole_heatmap(cellchat, pattern = "incoming",height=15)
ht1
ht2
# Out:
# plot without title
